# %%
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup

import pandas as pd

# %%
def get_soup(url):
    driver = webdriver.Chrome()  #webdriver modulünü cagirma
    driver.get(url)      # url ye gidecek
    response = driver.page_source  #age_source özelliğini kullanarak tarayıcı tarafından yüklenen HTML içeriğini alır.
    soup = BeautifulSoup(response, "html.parser")
    return soup

# %%
def get_govdata(soup):
    data = []
    page_info= soup.find_all('li', class_='resultentry design-box design-box-padding')
    
    
    for i in page_info:
      
      title_info = i.find("div", class_="column small-12 medium-8 large-9")
      title_find = title_info.find('a').text

      title = title_find.split("-",1)[1].strip()
#split methodu ile (-)burdan sonrasinin alip,indeksi 1 olani alip yazdirma islemi
      year_find = title_find.strip('_ ').split(" ")[0]

      

      url = title_info.find('a')['href'] if title_info.find('a') else None
      info = i.find("p", class_="h2-teaser").get_text(strip=True)
      
      kategorie_find = info.strip().split(" ")
      kategorie = kategorie_find[2]

      year_find_1= i.find("span", id="metadata_temporalCoverageFrom")
      first_date = year_find_1.text if year_find_1 else None  

      year_find_2 = i.find("span", id="metadata_temporalCoverageTo") 
      second_date = year_find_2.text if year_find_2 else None

  #info = i.find("div", class_="column small-12 medium-4 large-3")
# info2 = i.find("p", class_= "design-box design-box-padding").text
            # print(info2)
      print(f'Url : {url} ')
      print(f'Title: {title} ')
      print(f'info: {info}')
      print(f' Kategorie : {kategorie}')
      print(f'First_date: {first_date}')
      print(f'Second_date: {second_date}')
      print(f'Year: {year_find}')
           
      
     

      data.append({
            'Url': url,
            'Kategorie': kategorie,
            'Title': title,
            'Info': info,
            'Year': year_find,
            'First_date': first_date,
            'Second_date': second_date
              
    })

    
    return data

# %%
url = 'https://www.govdata.de/web/guest/daten/-/searchresult/f/type%3Adataset%2Csourceportal%3Abdc08f58-41dc-4f8a-a145-c019805bdeaf%2C/s/relevance_desc'
soup = get_soup(url)
show_data = get_govdata(soup)

df= pd.DataFrame(show_data)
print(df)
# Out:
# Url : https://www.govdata.de/web/guest/daten/-/details/___2021-polizeiliche-kriminalstatistik-t91-opfer-insgesamt-nach-alter-und-geschlecht-erwachsene-ab-6
# Title: T91 Opfer insgesamt nach Alter und Geschlecht Erwachsene...
# info: Informationen zu Opfern ab 60 Jahre - aufgegliedert nach Alter und Geschlecht und getrennt für vollendete Taten, Versuche und insgesamt nach ausgewaehlten Delikten, pro Kreis
#  Kategorie : Opfern
# First_date: 01.01.2021
# Second_date: 31.12.2021
# Year: 2021
# Url : https://www.govdata.de/web/guest/daten/-/details/___2021-polizeiliche-kriminalstatistik-t91-opfer-insgesamt-nach-alter-und-geschlecht-erweiterte-alte
# Title: T91 Opfer insgesamt nach Alter und Geschlecht erweiterte...
# info: Informationen zu Opfern - aufgegliedert nach Alter und Geschlecht und getrennt für vollendete Taten, Versuche und insgesamt nach ausgewaehlten Delikten mit zusaetzlichen Altersklassen, pro Kreis
#  Kategorie : Opfern
# First_date: 01.01.2021
# Second_date: 31.12.2021
# Year: 2021
# Url : https://www.govdata.de/web/guest/daten/-/details/_2021-polizeiliche-kriminalstatistik-t20-tatverdachtige-insgesamt-nach-alter-und-geschlecht-erwachse
# Title: T20 Tatverdächtige insgesamt nach Alter und Geschlecht Erw...
# info: Informationen zu tatverdaechtigen Erwachsenen ab 60 Jahre (Aufgliederung nach ausgewaehlten Delikten, Anzahl Tatverdaechtige insgesamt, nach Geschlecht, nach Alter) pro Kreis
#  Kategorie : tatverdaechtigen
# First_date: 01.01.2021
# Second_date: 31.12.2021
# Year: 2021
# Url : https://www.govdata.de/web/guest/daten/-/details/__2021-polizeiliche-kriminalstatistik-t91-opfer-insgesamt-nach-alter-und-geschlecht-erwachsene-ab-60
# Title: T91 Opfer insgesamt nach Alter und Geschlecht Erwachsene ...
# info: Informationen zu Opfern - aufgegliedert nach Alter und Geschlecht und getrennt für vollendete Taten, Versuche und insgesamt nach Delikten Erwachsene ab 60 Jahre, pro Bundesland
#  Kategorie : Opfern
# First_date: 01.01.2021
# Second_date: 31.12.2021
# Year: 2021
# Url : https://www.govdata.de/web/guest/daten/-/details/__2021-polizeiliche-kriminalstatistik-t91-opfer-insgesamt-nach-alter-und-geschlecht-erweiterte-alter
# Title: T91 Opfer insgesamt nach Alter und Geschlecht erweiterte ...
# info: Informationen zu Opfern - aufgegliedert nach Alter und Geschlecht und getrennt für vollendete Taten, Versuche und insgesamt nach Delikten mit zusaetzlichen Altersklassen, pro Bundesland
#  Kategorie : Opfern
# First_date: 01.01.2021
# Second_date: 31.12.2021
# Year: 2021
# Url : https://www.govdata.de/web/guest/daten/-/details/_2021-polizeiliche-kriminalstatistik-t61-nichtdeutsche-tatverdaechtige-nach-dem-anlass-des-aufenthal
# Title: T61 Nichtdeutsche Tatverdaechtige nach dem Anlass des Aufe...
# info: Informationen ueber den Anteil der maennlichen und weiblichen nichtdeutschen Tatverdaechtigen an der Gesamtzahl der ermittelten Tatverdaechtigen (ohne Ruecksicht auf die Staatsangehoerigkeit) sowoh...
#  Kategorie : den
# First_date: 01.01.2021
# Second_date: 31.12.2021
# Year: 2021
# Url : https://www.govdata.de/web/guest/daten/-/details/_2021-polizeiliche-kriminalstatistik-t50-tatverdaechtige-nichtdeutsch-nach-alter-und-geschlecht-erwa
# Title: T50 Tatverdaechtige nichtdeutsch nach Alter und Geschlecht...
# info: Informationen zu nichtdeutschen tatverdaechtigen Erwachsenen ab 60 Jahre (Aufgliederung nach Delikten, Anzahl Tatverdaechtige insgesamt, nach Geschlecht, nach Alter) pro Bundesland
#  Kategorie : nichtdeutschen
# First_date: 01.01.2021
# Second_date: 31.12.2021
# Year: 2021
# Url : https://www.govdata.de/web/guest/daten/-/details/_2021-polizeiliche-kriminalstatistik-t40-tatverdaechtige-deutsch-nach-alter-und-geschlecht-erwachsen
# Title: T40 Tatverdaechtige deutsch nach Alter und Geschlecht Erwa...
# info: Informationen zu deutschen tatverdaechtigen Erwachsenen ab 60 Jahre (Aufgliederung nach Delikten, Anzahl Tatverdaechtige insgesamt, nach Geschlecht, nach Alter) pro Bundesland
#  Kategorie : deutschen
# First_date: 01.01.2021
# Second_date: 31.12.2021
# Year: 2021
# Url : https://www.govdata.de/web/guest/daten/-/details/_2021-polizeiliche-kriminalstatistik-t20-tatverdaechtige-insgesamt-nach-alter-und-geschlecht-erwachs
# Title: T20 Tatverdaechtige insgesamt nach Alter und Geschlecht Er...
# info: Informationen zu tatverdaechtigen Erwachsenen ab 60 Jahre (Aufgliederung nach Delikten, Anzahl Tatverdaechtige insgesamt, nach Geschlecht, nach Alter) pro Bundesland
#  Kategorie : tatverdaechtigen
# First_date: 01.01.2021
# Second_date: 31.12.2021
# Year: 2021
# Url : https://www.govdata.de/web/guest/daten/-/details/_2021-polizeiliche-kriminalstatistik-t08-tatzeitstatistik
# Title: Polizeiliche Kriminalstatistik - T08 Tatzeitstatistik
# info: Informationen zur Tatzeit innerhalb des Berichtsjahres (Aufgliederung nach Delikten, Anzahl Faelle insgesamt, Tatmonat, Tatzeit unbekannt)
#  Kategorie : Tatzeit
# First_date: 01.01.2021
# Second_date: 31.12.2021
# Year: 2021
#                                                  Url         Kategorie  \
# 0  https://www.govdata.de/web/guest/daten/-/detai...            Opfern
# 1  https://www.govdata.de/web/guest/daten/-/detai...            Opfern
# 2  https://www.govdata.de/web/guest/daten/-/detai...  tatverdaechtigen
# 3  https://www.govdata.de/web/guest/daten/-/detai...            Opfern
# 4  https://www.govdata.de/web/guest/daten/-/detai...            Opfern
# 5  https://www.govdata.de/web/guest/daten/-/detai...               den
# 6  https://www.govdata.de/web/guest/daten/-/detai...    nichtdeutschen
# 7  https://www.govdata.de/web/guest/daten/-/detai...         deutschen
# 8  https://www.govdata.de/web/guest/daten/-/detai...  tatverdaechtigen
# 9  https://www.govdata.de/web/guest/daten/-/detai...           Tatzeit
#
#                                                Title  \
# 0  T91 Opfer insgesamt nach Alter und Geschlecht ...
# 1  T91 Opfer insgesamt nach Alter und Geschlecht ...
# 2  T20 Tatverdächtige insgesamt nach Alter und Ge...
# 3  T91 Opfer insgesamt nach Alter und Geschlecht ...
# 4  T91 Opfer insgesamt nach Alter und Geschlecht ...
# 5  T61 Nichtdeutsche Tatverdaechtige nach dem Anl...
# 6  T50 Tatverdaechtige nichtdeutsch nach Alter un...
# 7  T40 Tatverdaechtige deutsch nach Alter und Ges...
# 8  T20 Tatverdaechtige insgesamt nach Alter und G...
# 9  Polizeiliche Kriminalstatistik - T08 Tatzeitst...
#
#                                                 Info  Year  First_date  \
# 0  Informationen zu Opfern ab 60 Jahre - aufgegli...  2021  01.01.2021
# 1  Informationen zu Opfern - aufgegliedert nach A...  2021  01.01.2021
# 2  Informationen zu tatverdaechtigen Erwachsenen ...  2021  01.01.2021
# 3  Informationen zu Opfern - aufgegliedert nach A...  2021  01.01.2021
# 4  Informationen zu Opfern - aufgegliedert nach A...  2021  01.01.2021
# 5  Informationen ueber den Anteil der maennlichen...  2021  01.01.2021
# 6  Informationen zu nichtdeutschen tatverdaechtig...  2021  01.01.2021
# 7  Informationen zu deutschen tatverdaechtigen Er...  2021  01.01.2021
# 8  Informationen zu tatverdaechtigen Erwachsenen ...  2021  01.01.2021
# 9  Informationen zur Tatzeit innerhalb des Berich...  2021  01.01.2021
#
#   Second_date
# 0  31.12.2021
# 1  31.12.2021
# 2  31.12.2021
# 3  31.12.2021
# 4  31.12.2021
# 5  31.12.2021
# 6  31.12.2021
# 7  31.12.2021
# 8  31.12.2021
# 9  31.12.2021

# %%
df.head()
# Out:
#                                                  Url         Kategorie  \
# 0  https://www.govdata.de/web/guest/daten/-/detai...            Opfern
# 1  https://www.govdata.de/web/guest/daten/-/detai...            Opfern
# 2  https://www.govdata.de/web/guest/daten/-/detai...  tatverdaechtigen
# 3  https://www.govdata.de/web/guest/daten/-/detai...            Opfern
# 4  https://www.govdata.de/web/guest/daten/-/detai...            Opfern
#
#                                                Title  \
# 0  T91 Opfer insgesamt nach Alter und Geschlecht ...
# 1  T91 Opfer insgesamt nach Alter und Geschlecht ...
# 2  T20 Tatverdächtige insgesamt nach Alter und Ge...
# 3  T91 Opfer insgesamt nach Alter und Geschlecht ...
# 4  T91 Opfer insgesamt nach Alter und Geschlecht ...
#
#                                                 Info  Year  First_date  \
# 0  Informationen zu Opfern ab 60 Jahre - aufgegli...  2021  01.01.2021
# 1  Informationen zu Opfern - aufgegliedert nach A...  2021  01.01.2021
# 2  Informationen zu tatverdaechtigen Erwachsenen ...  2021  01.01.2021
# 3  Informationen zu Opfern - aufgegliedert nach A...  2021  01.01.2021
# 4  Informationen zu Opfern - aufgegliedert nach A...  2021  01.01.2021
#
#   Second_date
# 0  31.12.2021
# 1  31.12.2021
# 2  31.12.2021
# 3  31.12.2021
# 4  31.12.2021

# %% [markdown]
# def get_govdata(soup):
#     data = []
#
#     for i in page_info:
#
#         title = i.find("div", class_="column small-12 medium-8 large-9")
#         info = soup.h2.a.get('title') if soup.h2.a else None
#         url =
