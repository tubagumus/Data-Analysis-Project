# %%
import pandas as pd
from sqlalchemy import create_engine

#su an 6 ve 11 i aktarmadi,dosya isimlerini kisaltarak deniyorum.

# Dosya isimlerini ve SQL isimlerini belirtin
Dateinamen_csv = [
     "1_KR-O-03-T91-Kreise-Opfer-ab-60J_csv.csv",
     "2_KR-O-02-T91-Kreise-Opfer-Alter-erw_csv.csv",
     "3_KR-TV-02-T20-Kreise-TV-ab-60J_csv.csv",
     "4_LA-O-03-T91-Laender-Opfer-ab-60J_csv.csv",
     "5_LA-O-02-T91-Laender-Opfer-Alter-erw_csv.csv",
     #"6_LA_TV_ntdeutsch.csv",
     "7_LA_T_06_T50_TV_nichtdeutsch_ab60J.csv",
     "8_LA-TV-04-T40-Laender-TV-deutsch-ab-60J_csv.csv",
     "9_BU-O-03-T91-Opfer-ab-60J_csv.csv",
     "10_BU-O-02-T91-Alter-erw_csv.csv",
     #"11_BU_TV_07_T20_Mehrfach_Alkohol.csv"
]

SQLDateinamen_csv = [
    "01_Opfer_insgesamt_Ab60_Alter_Geschlecht_Bezirke",
    "02_Opfer_insgesamt_Alter_Geschlecht_Bezirke",
    "03_Tatverdächtige_insgesamt_ab60_Alter_Geschlecht",
    "04_Opfer_insgesamt_ab60_Alter_Geschlecht_Bundeslaender",
    "05_Opfer_insgesamt_Alter_Geschlecht_Bundeslaender",
    #"6_LA_TV_ntdeutsch",
    "07_Tv_Nichtdeutsche_ab60_Alter_Geschlecht_Bndslndr",
    "08_Tatverdachtige_deutsche_ab60_Alter_Geschlecht_Bundeslaender",
    "09_Opfer_insgesamt_ab60_Alter_Geschlecht",
    "10_Opfer_insgesamt_Alter_Geschlecht"]
   # "11_Tv_ab60_deutsche_unterAlkoholeinfluss"]

# Veritabanına bağlan
engine = create_engine('mysql+pymysql://kullanici_adi:sifre@127.0.0.1:3306/veritabani_adi?charset=utf8mb4')

engine = create_engine("mysql+pymysql://" + "root" + ":" + "qw123" + "@" + "127.0.0.1" + ":" + "3306" + "/" + "classicmodels" + "?" + "charset=utf8mb4")


for i, csv_file in enumerate(Dateinamen_csv):
    # CSV dosyasını oku ve hataları önle
    try:
        df = pd.read_csv(csv_file, encoding='latin1', sep=';', header=1, low_memory=False)
        #df = df.astype(str)
        df_name = f"df_{i}"  # DataFrame ismi
        globals()[df_name] = df  # DataFrame'i global bir değişkene ata
        rowcsv = df.shape[0]  # Satır sayısı
        wievielmal = rowcsv // 500
        Restwert = rowcsv % 500

        for _ in range(wievielmal):
            chunk = df.head(500)
            df = df.iloc[500:]
            chunk.to_sql(SQLDateinamen_csv[i], con=engine, if_exists="append", index=False)

        if Restwert > 0:
            df.head(Restwert).to_sql(SQLDateinamen_csv[i], con=engine, if_exists="append", index=False)

        print(f"{Dateinamen_csv[i]} {SQLDateinamen_csv[i]} ok")

    except Exception as e:
        print(f"Hata: {Dateinamen_csv[i]} dosyasını işlerken bir hata oluştu: {str(e)}")

print("Fertig")
